# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\lchang_axc\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\lchang_axc\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
#Import the dependencies
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import requests
from config import weather_api_key
weather_api_key
# Out:
# '7cf94c01e5b6b153d7d238d51d240f0c'

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7cf94c01e5b6b153d7d238d51d240f0c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description":city_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print()
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | gao
# Processing Record 4 of Set 1 | gallup
# Processing Record 5 of Set 1 | victoria
# Processing Record 6 of Set 1 | andenes
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | japura
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | palmas
# Processing Record 11 of Set 1 | uglich
# Processing Record 12 of Set 1 | palmer
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | nkoteng
# Processing Record 16 of Set 1 | zambezi
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | yar-sale
# Processing Record 21 of Set 1 | beringovskiy
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | bulawayo
# Processing Record 25 of Set 1 | mount isa
# Processing Record 26 of Set 1 | gourcy
# Processing Record 27 of Set 1 | honningsvag
# Processing Record 28 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 1 | bilma
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | caborca
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | sigli
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | zaragoza
# Processing Record 37 of Set 1 | port hardy
# Processing Record 38 of Set 1 | tahe
# Processing Record 39 of Set 1 | seminole
# Processing Record 40 of Set 1 | gaoua
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | swellendam
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | fredonia
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | songjianghe
# Processing Record 4 of Set 2 | hokitika
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | gillette
# Processing Record 8 of Set 2 | turukhansk
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | bonthe
# Processing Record 11 of Set 2 | igarka
# Processing Record 12 of Set 2 | natal
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | harwich
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | lyubar
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | dombas
# Processing Record 19 of Set 2 | lompoc
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 22 of Set 2 | ahipara
# Processing Record 23 of Set 2 | amapa
# Processing Record 24 of Set 2 | fukue
# Processing Record 25 of Set 2 | leningradskiy
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | asuncion
# Processing Record 30 of Set 2 | ayan
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | onega
# Processing Record 33 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 2 | koshurnikovo
# Processing Record 35 of Set 2 | rocha
# Processing Record 36 of Set 2 | lorengau
# Processing Record 37 of Set 2 | birjand
# Processing Record 38 of Set 2 | floro
# Processing Record 39 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | mahibadhoo
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | mizdah
# Processing Record 44 of Set 2 | cockburn town
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | kalemie
# Processing Record 47 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 48 of Set 2 | warrington
# Processing Record 49 of Set 2 | deputatskiy
# Processing Record 50 of Set 2 | grimshaw
# Processing Record 1 of Set 3 | tallahassee
# Processing Record 2 of Set 3 | vrangel
# Processing Record 3 of Set 3 | berlevag
# Processing Record 4 of Set 3 | ayorou
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 3 | kuching
# Processing Record 8 of Set 3 | whitehorse
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | abadan
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | hasaki
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | paucartambo
# City not found. Skipping...
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | ayr
# Processing Record 20 of Set 3 | porto novo
# Processing Record 21 of Set 3 | santa isabel
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | tolaga bay
# Processing Record 24 of Set 3 | nhulunbuy
# Processing Record 25 of Set 3 | yulara
# Processing Record 26 of Set 3 | lazaro cardenas
# Processing Record 27 of Set 3 | pacific grove
# Processing Record 28 of Set 3 | itarema
# Processing Record 29 of Set 3 | keflavik
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 3 | saldanha
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | asau
# Processing Record 36 of Set 3 | caninde de sao francisco
# Processing Record 37 of Set 3 | chita
# Processing Record 38 of Set 3 | dondo
# Processing Record 39 of Set 3 | kropotkin
# Processing Record 40 of Set 3 | aklavik
# Processing Record 41 of Set 3 | dudinka
# Processing Record 42 of Set 3 | sangar
# Processing Record 43 of Set 3 | vardo
# Processing Record 44 of Set 3 | sayabec
# City not found. Skipping...
# Processing Record 45 of Set 3 | ketchikan
# Processing Record 46 of Set 3 | kieta
# Processing Record 47 of Set 3 | kumluca
# Processing Record 48 of Set 3 | picos
# Processing Record 49 of Set 3 | la ronge
# Processing Record 50 of Set 3 | rodniki
# Processing Record 1 of Set 4 | iquique
# Processing Record 2 of Set 4 | seoni
# Processing Record 3 of Set 4 | antofagasta
# Processing Record 4 of Set 4 | gaya
# Processing Record 5 of Set 4 | atar
# Processing Record 6 of Set 4 | kjollefjord
# Processing Record 7 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 4 | helong
# Processing Record 9 of Set 4 | havre-saint-pierre
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | todos santos
# Processing Record 13 of Set 4 | waverly
# Processing Record 14 of Set 4 | rudnyy
# Processing Record 15 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 4 | alyangula
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 4 | bathsheba
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | matara
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | chake chake
# Processing Record 24 of Set 4 | tual
# Processing Record 25 of Set 4 | nikolskoye
# Processing Record 26 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 27 of Set 4 | talnakh
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | saint-francois
# Processing Record 30 of Set 4 | teya
# Processing Record 31 of Set 4 | makaha
# Processing Record 32 of Set 4 | uige
# Processing Record 33 of Set 4 | naantali
# Processing Record 34 of Set 4 | jalu
# Processing Record 35 of Set 4 | alamogordo
# Processing Record 36 of Set 4 | samarai
# Processing Record 37 of Set 4 | caravelas
# Processing Record 38 of Set 4 | santa rosa
# Processing Record 39 of Set 4 | al
# City not found. Skipping...
# Processing Record 40 of Set 4 | lorena
# Processing Record 41 of Set 4 | xuddur
# Processing Record 42 of Set 4 | bethel
# Processing Record 43 of Set 4 | manokwari
# Processing Record 44 of Set 4 | zeya
# Processing Record 45 of Set 4 | pondicherry
# Processing Record 46 of Set 4 | dikson
# Processing Record 47 of Set 4 | den helder
# Processing Record 48 of Set 4 | beyneu
# Processing Record 49 of Set 4 | puerto ayacucho
# Processing Record 50 of Set 4 | loreto
# Processing Record 1 of Set 5 | imbituba
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | bacolod
# Processing Record 6 of Set 5 | klamath falls
# Processing Record 7 of Set 5 | bluff
# Processing Record 8 of Set 5 | ust-kuyga
# Processing Record 9 of Set 5 | abu zabad
# Processing Record 10 of Set 5 | sobolevo
# Processing Record 11 of Set 5 | yantal
# Processing Record 12 of Set 5 | jasper
# Processing Record 13 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 14 of Set 5 | havelock
# Processing Record 15 of Set 5 | grand-santi
# Processing Record 16 of Set 5 | severnoye
# Processing Record 17 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 5 | zabaykalsk
# Processing Record 19 of Set 5 | gavle
# Processing Record 20 of Set 5 | xunchang
# Processing Record 21 of Set 5 | papar
# Processing Record 22 of Set 5 | luderitz
# Processing Record 23 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | mehamn
# Processing Record 25 of Set 5 | djibo
# Processing Record 26 of Set 5 | batemans bay
# Processing Record 27 of Set 5 | darhan
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 5 | constitucion
# Processing Record 32 of Set 5 | buala
# Processing Record 33 of Set 5 | grindavik
# Processing Record 34 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | vila velha
# Processing Record 37 of Set 5 | alugan
# Processing Record 38 of Set 5 | saint-pierre
# Processing Record 39 of Set 5 | yambio
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | sitka
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | laguna
# Processing Record 45 of Set 5 | tuktoyaktuk
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | ust-kulom
# Processing Record 48 of Set 5 | acarau
# Processing Record 49 of Set 5 | arcachon
# Processing Record 50 of Set 5 | verkhniy fiagdon
# Processing Record 1 of Set 6 | georgetown
# Processing Record 2 of Set 6 | nantucket
# Processing Record 3 of Set 6 | ilanskiy
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | moundou
# Processing Record 6 of Set 6 | malanje
# Processing Record 7 of Set 6 | tatawin
# Processing Record 8 of Set 6 | orbetello
# Processing Record 9 of Set 6 | panalingaan
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | vila
# Processing Record 12 of Set 6 | nordborg
# Processing Record 13 of Set 6 | gornopravdinsk
# Processing Record 14 of Set 6 | kahului
# Processing Record 15 of Set 6 | marabba
# Processing Record 16 of Set 6 | oyem
# Processing Record 17 of Set 6 | lima
# Processing Record 18 of Set 6 | oyama
# Processing Record 19 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 6 | garowe
# Processing Record 21 of Set 6 | souillac
# Processing Record 22 of Set 6 | tucuman
# Processing Record 23 of Set 6 | klaksvik
# Processing Record 24 of Set 6 | labuhan
# Processing Record 25 of Set 6 | comodoro rivadavia
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | cervo
# Processing Record 28 of Set 6 | port hedland
# Processing Record 29 of Set 6 | malumfashi
# Processing Record 30 of Set 6 | zelenoborsk
# Processing Record 31 of Set 6 | bubaque
# Processing Record 32 of Set 6 | panuco
# Processing Record 33 of Set 6 | cap malheureux
# Processing Record 34 of Set 6 | kitaibaraki
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | steamboat springs
# Processing Record 37 of Set 6 | porto velho
# Processing Record 38 of Set 6 | port lincoln
# Processing Record 39 of Set 6 | ostrovnoy
# Processing Record 40 of Set 6 | akcaabat
# Processing Record 41 of Set 6 | quirinopolis
# Processing Record 42 of Set 6 | owando
# Processing Record 43 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 6 | kotido
# Processing Record 45 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 6 | yingcheng
# Processing Record 47 of Set 6 | valparaiso
# Processing Record 48 of Set 6 | dutse
# Processing Record 49 of Set 6 | port keats
# Processing Record 50 of Set 6 | gat
# Processing Record 1 of Set 7 | vila franca do campo
# Processing Record 2 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 7 | alekseyevsk
# Processing Record 4 of Set 7 | gaspe
# Processing Record 5 of Set 7 | huangmei
# Processing Record 6 of Set 7 | rassvet
# Processing Record 7 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 9 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 10 of Set 7 | karwar
# Processing Record 11 of Set 7 | goldsboro
# Processing Record 12 of Set 7 | kulhudhuffushi
# Processing Record 13 of Set 7 | itaituba
# Processing Record 14 of Set 7 | taywarah
# Processing Record 15 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 7 | torbay
# Processing Record 18 of Set 7 | zasheyek
# Processing Record 19 of Set 7 | iskateley
# Processing Record 20 of Set 7 | huntington
# Processing Record 21 of Set 7 | boa vista
# Processing Record 22 of Set 7 | khor
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | qeshm
# Processing Record 25 of Set 7 | takoradi
# Processing Record 26 of Set 7 | kruisfontein
# Processing Record 27 of Set 7 | nizhniy odes
# Processing Record 28 of Set 7 | mount gambier
# Processing Record 29 of Set 7 | tiksi
# Processing Record 30 of Set 7 | shebalino
# Processing Record 31 of Set 7 | jalingo
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | mao
# Processing Record 34 of Set 7 | keroka
# Processing Record 35 of Set 7 | zakharovo
# Processing Record 36 of Set 7 | kabompo
# Processing Record 37 of Set 7 | esil
# Processing Record 38 of Set 7 | evensk
# Processing Record 39 of Set 7 | aswan
# Processing Record 40 of Set 7 | roma
# Processing Record 41 of Set 7 | kualakapuas
# Processing Record 42 of Set 7 | nelidovo
# Processing Record 43 of Set 7 | dunedin
# Processing Record 44 of Set 7 | bairiki
# Processing Record 45 of Set 7 | port hawkesbury
# Processing Record 46 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 47 of Set 7 | kavieng
# Processing Record 48 of Set 7 | tessalit
# Processing Record 49 of Set 7 | aleksandrov gay
# Processing Record 50 of Set 7 | chifeng
# Processing Record 1 of Set 8 | sabzevar
# Processing Record 2 of Set 8 | sao filipe
# Processing Record 3 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 4 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 8 | huanren
# Processing Record 6 of Set 8 | svetlogorsk
# Processing Record 7 of Set 8 | bereda
# Processing Record 8 of Set 8 | lagos
# Processing Record 9 of Set 8 | kekri
# Processing Record 10 of Set 8 | belmonte
# Processing Record 11 of Set 8 | san ramon
# Processing Record 12 of Set 8 | sinnamary
# Processing Record 13 of Set 8 | thompson
# Processing Record 14 of Set 8 | puerto leguizamo
# Processing Record 15 of Set 8 | nassau
# Processing Record 16 of Set 8 | dargaville
# Processing Record 17 of Set 8 | puerto escondido
# Processing Record 18 of Set 8 | nabire
# Processing Record 19 of Set 8 | ternate
# Processing Record 20 of Set 8 | tsumeb
# Processing Record 21 of Set 8 | preobrazheniye
# Processing Record 22 of Set 8 | north bend
# Processing Record 23 of Set 8 | san andres
# Processing Record 24 of Set 8 | codrington
# Processing Record 25 of Set 8 | elat
# Processing Record 26 of Set 8 | mungwi
# Processing Record 27 of Set 8 | viransehir
# Processing Record 28 of Set 8 | mumford
# Processing Record 29 of Set 8 | nelson bay
# Processing Record 30 of Set 8 | weiswampach
# Processing Record 31 of Set 8 | sokoni
# Processing Record 32 of Set 8 | racine
# Processing Record 33 of Set 8 | batouri
# Processing Record 34 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 8 | jardim
# Processing Record 36 of Set 8 | groningen
# Processing Record 37 of Set 8 | bandarbeyla
# Processing Record 38 of Set 8 | magdagachi
# Processing Record 39 of Set 8 | tautira
# Processing Record 40 of Set 8 | kenai
# Processing Record 41 of Set 8 | dukat
# Processing Record 42 of Set 8 | fort nelson
# Processing Record 43 of Set 8 | hirara
# Processing Record 44 of Set 8 | yumen
# Processing Record 45 of Set 8 | ingham
# Processing Record 46 of Set 8 | ca mau
# Processing Record 47 of Set 8 | atbasar
# Processing Record 48 of Set 8 | sakakah
# Processing Record 49 of Set 8 | dali
# Processing Record 50 of Set 8 | praia da vitoria
# Processing Record 1 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 9 | prado
# Processing Record 3 of Set 9 | pori
# Processing Record 4 of Set 9 | faridan
# City not found. Skipping...
# Processing Record 5 of Set 9 | shache
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | lisakovsk
# Processing Record 8 of Set 9 | estelle
# Processing Record 9 of Set 9 | buraydah
# Processing Record 10 of Set 9 | meulaboh
# Processing Record 11 of Set 9 | turayf
# Processing Record 12 of Set 9 | komsomolskiy
# Processing Record 13 of Set 9 | kencong
# Processing Record 14 of Set 9 | elizabeth city
# Processing Record 15 of Set 9 | namibe
# Processing Record 16 of Set 9 | makakilo city
# Processing Record 17 of Set 9 | ambilobe
# Processing Record 18 of Set 9 | hami
# Processing Record 19 of Set 9 | acapulco
# Processing Record 20 of Set 9 | gimli
# Processing Record 21 of Set 9 | coquimbo
# Processing Record 22 of Set 9 | karaj
# Processing Record 23 of Set 9 | filadelfia
# Processing Record 24 of Set 9 | cidreira
# Processing Record 25 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 9 | tsaratanana
# Processing Record 27 of Set 9 | tanout
# Processing Record 28 of Set 9 | cabedelo
# Processing Record 29 of Set 9 | kaitangata
# Processing Record 30 of Set 9 | ashland
# Processing Record 31 of Set 9 | margate
# Processing Record 32 of Set 9 | jining
# Processing Record 33 of Set 9 | rabaul
# Processing Record 34 of Set 9 | pisco
# Processing Record 35 of Set 9 | whitianga
# Processing Record 36 of Set 9 | vilhena
# Processing Record 37 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 9 | alta floresta
# Processing Record 39 of Set 9 | arrecife
# Processing Record 40 of Set 9 | rawson
# Processing Record 41 of Set 9 | mahon
# Processing Record 42 of Set 9 | la libertad
# Processing Record 43 of Set 9 | kopong
# Processing Record 44 of Set 9 | san jeronimo
# Processing Record 45 of Set 9 | husavik
# Processing Record 46 of Set 9 | spirovo
# Processing Record 47 of Set 9 | rota
# Processing Record 48 of Set 9 | batagay-alyta
# Processing Record 49 of Set 9 | lebu
# Processing Record 50 of Set 9 | hegang
# Processing Record 1 of Set 10 | kiunga
# Processing Record 2 of Set 10 | lubango
# Processing Record 3 of Set 10 | adrar
# Processing Record 4 of Set 10 | pokaran
# Processing Record 5 of Set 10 | isangel
# Processing Record 6 of Set 10 | petauke
# Processing Record 7 of Set 10 | along
# Processing Record 8 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 10 | mareeba
# Processing Record 10 of Set 10 | egvekinot
# Processing Record 11 of Set 10 | hambantota
# Processing Record 12 of Set 10 | bima
# Processing Record 13 of Set 10 | nizhniy kuranakh
# Processing Record 14 of Set 10 | coahuayana
# Processing Record 15 of Set 10 | katherine
# Processing Record 16 of Set 10 | cayenne
# Processing Record 17 of Set 10 | alofi
# Processing Record 18 of Set 10 | nacala
# Processing Record 19 of Set 10 | vestmannaeyjar
# Processing Record 20 of Set 10 | dingle
# Processing Record 21 of Set 10 | san pascual
# Processing Record 22 of Set 10 | howard springs
# Processing Record 23 of Set 10 | udachnyy
# Processing Record 24 of Set 10 | lincoln
# Processing Record 25 of Set 10 | kizhinga
# Processing Record 26 of Set 10 | kishni
# Processing Record 27 of Set 10 | iracoubo
# Processing Record 28 of Set 10 | bonanza
# Processing Record 29 of Set 10 | thaton
# Processing Record 30 of Set 10 | vaitape
# Processing Record 31 of Set 10 | goderich
# Processing Record 32 of Set 10 | nha trang
# Processing Record 33 of Set 10 | basco
# Processing Record 34 of Set 10 | zhob
# Processing Record 35 of Set 10 | jonesboro
# Processing Record 36 of Set 10 | atikokan
# Processing Record 37 of Set 10 | karratha
# Processing Record 38 of Set 10 | ponferrada
# Processing Record 39 of Set 10 | sun valley
# Processing Record 40 of Set 10 | tari
# Processing Record 41 of Set 10 | tiznit
# Processing Record 42 of Set 10 | sambava
# Processing Record 43 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 10 | lermontovka
# Processing Record 45 of Set 10 | taquarituba
# Processing Record 46 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 10 | le port
# Processing Record 48 of Set 10 | vanimo
# Processing Record 49 of Set 10 | vao
# Processing Record 50 of Set 10 | los llanos de aridane
# Processing Record 1 of Set 11 | montrose
# Processing Record 2 of Set 11 | cairns
# Processing Record 3 of Set 11 | bloemhof
# Processing Record 4 of Set 11 | utica
# Processing Record 5 of Set 11 | casablanca
# Processing Record 6 of Set 11 | carballo
# Processing Record 7 of Set 11 | turhal
# Processing Record 8 of Set 11 | gari
# Processing Record 9 of Set 11 | gollere
# City not found. Skipping...
# Processing Record 10 of Set 11 | tucuma
# Processing Record 11 of Set 11 | ravensburg
# Processing Record 12 of Set 11 | kyzyl
# Processing Record 13 of Set 11 | pokrovka
# Processing Record 14 of Set 11 | abu samrah
# Processing Record 15 of Set 11 | te anau
# Processing Record 16 of Set 11 | gornyak
# Processing Record 17 of Set 11 | anqing
# Processing Record 18 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 11 | inhambane
# Processing Record 20 of Set 11 | palauig
# Processing Record 21 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 11 | coihaique
# Processing Record 23 of Set 11 | vostok
# Processing Record 24 of Set 11 | tonantins
# Processing Record 25 of Set 11 | boende
# Processing Record 26 of Set 11 | hagere selam
# Processing Record 27 of Set 11 | ossora
# Processing Record 28 of Set 11 | charters towers
# Processing Record 29 of Set 11 | hopkinsville
# Processing Record 30 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 11 | arlit
# Processing Record 32 of Set 11 | inirida
# Processing Record 33 of Set 11 | salinopolis
# Processing Record 34 of Set 11 | grants
# Processing Record 35 of Set 11 | ville-marie
# Processing Record 36 of Set 11 | mogadishu
# Processing Record 37 of Set 11 | parabel
# Processing Record 38 of Set 11 | nome
# Processing Record 39 of Set 11 | sumbe
# Processing Record 40 of Set 11 | taoudenni
# Processing Record 41 of Set 11 | mlonggo
# Processing Record 42 of Set 11 | leczna
# Processing Record 43 of Set 11 | rudbar
# Processing Record 44 of Set 11 | jurmala
# Processing Record 45 of Set 11 | kudahuvadhoo
# Processing Record 46 of Set 11 | bismarck
# Processing Record 47 of Set 11 | tahta
# Processing Record 48 of Set 11 | kushima
# Processing Record 49 of Set 11 | dedza
# Processing Record 50 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 2 of Set 12 | cajnice
# Processing Record 3 of Set 12 | ixtapa
# Processing Record 4 of Set 12 | torrington
# Processing Record 5 of Set 12 | nizwa
# Processing Record 6 of Set 12 | wenatchee
# Processing Record 7 of Set 12 | wanaka
# Processing Record 8 of Set 12 | alice springs
# Processing Record 9 of Set 12 | sao joao da barra
# Processing Record 10 of Set 12 | saint-michel-des-saints
# Processing Record 11 of Set 12 | oranjemund
# Processing Record 12 of Set 12 | bintulu
# Processing Record 13 of Set 12 | odweyne
# Processing Record 14 of Set 12 | gazanjyk
# Processing Record 15 of Set 12 | vilyuysk
# Processing Record 16 of Set 12 | mana
# Processing Record 17 of Set 12 | san cristobal
# Processing Record 18 of Set 12 | timizart
# Processing Record 19 of Set 12 | nanortalik
# Processing Record 20 of Set 12 | ulladulla
# Processing Record 21 of Set 12 | zhigansk
# Processing Record 22 of Set 12 | santa isabel do rio negro
# Processing Record 23 of Set 12 | olafsvik
# Processing Record 24 of Set 12 | san jose
# Processing Record 25 of Set 12 | oktyabrskiy
# Processing Record 26 of Set 12 | rincon
# Processing Record 27 of Set 12 | portland
# Processing Record 28 of Set 12 | matsanga
# City not found. Skipping...
# Processing Record 29 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 12 | juneau
# Processing Record 31 of Set 12 | dawei
# Processing Record 32 of Set 12 | baruun-urt
# Processing Record 33 of Set 12 | kybartai
# Processing Record 34 of Set 12 | haines junction
# Processing Record 35 of Set 12 | aktau
# Processing Record 36 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 12 | luganville
# Processing Record 38 of Set 12 | loukhi
# Processing Record 39 of Set 12 | saint anthony
# Processing Record 40 of Set 12 | isabela
# Processing Record 41 of Set 12 | goleta
# Processing Record 42 of Set 12 | kushmurun
# Processing Record 43 of Set 12 | madingou
# Processing Record 44 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 12 | broome
# Processing Record 46 of Set 12 | srednekolymsk
# Processing Record 47 of Set 12 | fereydunshahr
# Processing Record 48 of Set 12 | lesosibirsk
# Processing Record 49 of Set 12 | oussouye
# Processing Record 50 of Set 12 | guerrero negro
# Processing Record 1 of Set 13 | new london
# Processing Record 2 of Set 13 | mundra
# Processing Record 3 of Set 13 | orlik
# Processing Record 4 of Set 13 | namatanai
# Processing Record 5 of Set 13 | melo
# Processing Record 6 of Set 13 | eyl
# Processing Record 7 of Set 13 | kampot
# Processing Record 8 of Set 13 | crowley
# Processing Record 9 of Set 13 | aksarka
# Processing Record 10 of Set 13 | virginia beach
# Processing Record 11 of Set 13 | fuerte
# Processing Record 12 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 13 | lata
# Processing Record 14 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 13 | seymchan
# Processing Record 16 of Set 13 | abay
# Processing Record 17 of Set 13 | itaparica
# Processing Record 18 of Set 13 | xichang
# Processing Record 19 of Set 13 | bemidji
# Processing Record 20 of Set 13 | careiro da varzea
# Processing Record 21 of Set 13 | lufilufi
# Processing Record 22 of Set 13 | agadir
# Processing Record 23 of Set 13 | inuvik
# Processing Record 24 of Set 13 | toftir
# City not found. Skipping...
# Processing Record 25 of Set 13 | sorland
# Processing Record 26 of Set 13 | toora-khem
# Processing Record 27 of Set 13 | galle
# Processing Record 28 of Set 13 | poum
# Processing Record 29 of Set 13 | salinas
# Processing Record 30 of Set 13 | bjornevatn
# Processing Record 31 of Set 13 | abha
# Processing Record 32 of Set 13 | punta cardon
# Processing Record 33 of Set 13 | maracas
# Processing Record 34 of Set 13 | faya
# Processing Record 35 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 36 of Set 13 | sale
# Processing Record 37 of Set 13 | samastipur
# Processing Record 38 of Set 13 | bolonchen
# City not found. Skipping...
# Processing Record 39 of Set 13 | keita
# Processing Record 40 of Set 13 | tarpon springs
# Processing Record 41 of Set 13 | paveh
# Processing Record 42 of Set 13 | nemuro
# Processing Record 43 of Set 13 | kununurra
# Processing Record 44 of Set 13 | puri
# Processing Record 45 of Set 13 | saint marys
# Processing Record 46 of Set 13 | shihezi
# Processing Record 47 of Set 13 | hofn
# Processing Record 48 of Set 13 | parelhas
# Processing Record 49 of Set 13 | manggar
# Processing Record 50 of Set 13 | rantauprapat
# Processing Record 1 of Set 14 | beloha
# Processing Record 2 of Set 14 | ilulissat
# Processing Record 3 of Set 14 | okhotsk
# Processing Record 4 of Set 14 | saint-joseph
# Processing Record 5 of Set 14 | ewa beach
# Processing Record 6 of Set 14 | kijang
# Processing Record 7 of Set 14 | awjilah
# Processing Record 8 of Set 14 | taltal
# Processing Record 9 of Set 14 | kendari
# Processing Record 10 of Set 14 | koulikoro
# Processing Record 11 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 14 | boulder
# Processing Record 13 of Set 14 | henties bay
# Processing Record 14 of Set 14 | seybaplaya
# Processing Record 15 of Set 14 | severo-yeniseyskiy
# Processing Record 16 of Set 14 | sikasso
# Processing Record 17 of Set 14 | yekaterinoslavka
# Processing Record 18 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 14 | doha
# Processing Record 20 of Set 14 | colon
# Processing Record 21 of Set 14 | liverpool
# Processing Record 22 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 14 | bacsalmas
# Processing Record 24 of Set 14 | la rioja
# Processing Record 25 of Set 14 | palora
# Processing Record 26 of Set 14 | sidney
# Processing Record 27 of Set 14 | muisne
# Processing Record 28 of Set 14 | harper
# Processing Record 29 of Set 14 | shingu
# Processing Record 30 of Set 14 | carlagan
# Processing Record 31 of Set 14 | adre
# Processing Record 32 of Set 14 | nivala
# Processing Record 33 of Set 14 | puerto colombia
# Processing Record 34 of Set 14 | tura
# Processing Record 35 of Set 14 | araouane
# Processing Record 36 of Set 14 | morgan city
# Processing Record 37 of Set 14 | cedar city
# Processing Record 38 of Set 14 | petrovsk-zabaykalskiy
# Processing Record 39 of Set 14 | williamsport
# Processing Record 40 of Set 14 | roald
# Processing Record 41 of Set 14 | gondar
# Processing Record 42 of Set 14 | rio gallegos
# Processing Record 43 of Set 14 | matay
# Processing Record 44 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 14 | san nicola
# Processing Record 46 of Set 14 | kamenka
# Processing Record 47 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 14 | bokoro
# Processing Record 49 of Set 14 | sayyan
# Processing Record 50 of Set 14 | padang
# Processing Record 1 of Set 15 | manacapuru
# Processing Record 2 of Set 15 | vesyegonsk
# Processing Record 3 of Set 15 | champerico
# Processing Record 4 of Set 15 | khanion tou kokkini
# City not found. Skipping...
# Processing Record 5 of Set 15 | carroll
# Processing Record 6 of Set 15 | tunxi
# City not found. Skipping...
# Processing Record 7 of Set 15 | kayes
# Processing Record 8 of Set 15 | dong hoi
# Processing Record 9 of Set 15 | caucaia
# Processing Record 10 of Set 15 | yerofey pavlovich
# Processing Record 11 of Set 15 | lixourion
# Processing Record 12 of Set 15 | biak
# Processing Record 13 of Set 15 | chaochou
# City not found. Skipping...
# Processing Record 14 of Set 15 | izumo
# Processing Record 15 of Set 15 | tabou
# Processing Record 16 of Set 15 | charlestown
# Processing Record 17 of Set 15 | zverinogolovskoye
# Processing Record 18 of Set 15 | parvatipuram
# Processing Record 19 of Set 15 | luba
# Processing Record 20 of Set 15 | pueblo nuevo
# Processing Record 21 of Set 15 | plettenberg bay
# Processing Record 22 of Set 15 | hue
# Processing Record 23 of Set 15 | jinchang
# Processing Record 24 of Set 15 | tekkali
# Processing Record 25 of Set 15 | pangnirtung
# Processing Record 26 of Set 15 | broken hill
# Processing Record 27 of Set 15 | raudeberg
# Processing Record 28 of Set 15 | tecoanapa
# Processing Record 29 of Set 15 | miles city
# Processing Record 30 of Set 15 | goudomp
# City not found. Skipping...
# Processing Record 31 of Set 15 | pontianak
# Processing Record 32 of Set 15 | sola
# Processing Record 33 of Set 15 | fare
# Processing Record 34 of Set 15 | camacha
# Processing Record 35 of Set 15 | carbonia
# Processing Record 36 of Set 15 | conakry
# Processing Record 37 of Set 15 | lobito
# Processing Record 38 of Set 15 | moron
# Processing Record 39 of Set 15 | albion
# Processing Record 40 of Set 15 | asfi
# Processing Record 41 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 15 | kingaroy
# Processing Record 43 of Set 15 | nuuk
# Processing Record 44 of Set 15 | hovd
# Processing Record 45 of Set 15 | riberalta
# Processing Record 46 of Set 15 | orange cove
# Processing Record 47 of Set 15 | kebumen
# Processing Record 48 of Set 15 | prince rupert
# Processing Record 49 of Set 15 | nakamura
# Processing Record 50 of Set 15 | miri
# Processing Record 1 of Set 16 | petrozavodsk
# Processing Record 2 of Set 16 | povenets
# Processing Record 3 of Set 16 | tangkak
# Processing Record 4 of Set 16 | kabo
# Processing Record 5 of Set 16 | mayo
# Processing Record 6 of Set 16 | reshetnikovo
# Processing Record 7 of Set 16 | marquette
# Processing Record 8 of Set 16 | sisimiut
# Processing Record 9 of Set 16 | rundu
# Processing Record 10 of Set 16 | marzuq
# Processing Record 11 of Set 16 | yenagoa
# Processing Record 12 of Set 16 | carutapera
# Processing Record 13 of Set 16 | tarko-sale
# Processing Record 14 of Set 16 | sukhodol
# Processing Record 15 of Set 16 | bucerias
# Processing Record 16 of Set 16 | wajir
# Processing Record 17 of Set 16 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 16 | chaadayevka
# Processing Record 19 of Set 16 | burkhala
# City not found. Skipping...
# Processing Record 20 of Set 16 | olga
# Processing Record 21 of Set 16 | flinders
# Processing Record 22 of Set 16 | loikaw
# Processing Record 23 of Set 16 | antsohihy
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hilo  19.7297 -155.0900     77.00        65          90
# 1         Atuona  -9.8000 -139.0333     78.37        77          52
# 2            Gao  16.6362    1.6370     72.88        17          95
# 3         Gallup  35.5281 -108.7426     55.40        16           1
# 4       Victoria  22.2855  114.1577     55.00        51          96
# ..           ...      ...       ...       ...       ...         ...
# 697  Chaadayevka  53.1427   45.9122     -9.26        89          97
# 698         Olga  43.7444  135.2892      1.29        85          60
# 699     Flinders -34.5833  150.8552     69.01        77          20
# 700       Loikaw  19.6742   97.2094     55.20        71           5
# 701    Antsohihy -14.8796   47.9875     77.04        94           9
#
#      Wind Speed Country      Description
# 0          8.05      US       light rain
# 1         14.70      PF    broken clouds
# 2         11.36      ML  overcast clouds
# 3         13.80      US        clear sky
# 4         10.47      HK  overcast clouds
# ..          ...     ...              ...
# 697        0.45      RU  overcast clouds
# 698        3.74      RU    broken clouds
# 699        1.99      AU       few clouds
# 700        1.54      MM        clear sky
# 701        1.54      MG       light rain
#
# [702 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(14)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hilo      US  19.7297 -155.0900     77.00        65          90
# 1         Atuona      PF  -9.8000 -139.0333     78.37        77          52
# 2            Gao      ML  16.6362    1.6370     72.88        17          95
# 3         Gallup      US  35.5281 -108.7426     55.40        16           1
# 4       Victoria      HK  22.2855  114.1577     55.00        51          96
# 5        Andenes      NO  69.3143   16.1194     30.20        93          75
# 6        Iqaluit      CA  63.7506  -68.5145    -13.00        70          20
# 7         Japura      ID  -0.3167  102.3500     72.37        97         100
# 8      Cape Town      ZA -33.9258   18.4232     71.60        60           0
# 9         Palmas      BR -10.2128  -48.3603     78.80        83          40
# 10        Uglich      RU  57.5275   38.3317     -9.40        88          15
# 11        Palmer      US  42.1584  -72.3287     39.99        56          90
# 12         Ancud      CL -41.8697  -73.8203     66.20        63           0
# 13  Punta Arenas      CL -53.1500  -70.9167     62.60        59          40
#
#     Wind Speed       Description
# 0         8.05        light rain
# 1        14.70     broken clouds
# 2        11.36   overcast clouds
# 3        13.80         clear sky
# 4        10.47   overcast clouds
# 5         8.05        light snow
# 6         6.91        few clouds
# 7         2.66   overcast clouds
# 8        17.27         clear sky
# 9         4.61     moderate rain
# 10        4.00        few clouds
# 11        8.05   overcast clouds
# 12       10.36         clear sky
# 13       29.93  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
